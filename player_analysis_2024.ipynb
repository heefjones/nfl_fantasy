# %% [markdown]
# # 2024
# Now, we have raw fantasy point projections for each player. These projections only take into account a player's career statistics. They do not factor in the __team/system__ around the player, which can be very important. From this [notebook](eda/eda.ipynb), we know that some external variables are important to prediciting fantasy success. Here, we will factor these externals in with player projections to create more accurate 2024 rankings.

# %%
# data science stuff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# models
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, StackingRegressor
from xgboost import XGBRegressor
from sklearn.pipeline import Pipeline

# data preprocessing, performance metrics
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.metrics import r2_score, mean_squared_error

# display
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# global random_state
random_state = 9

# %%
# load data
master = pd.read_csv('data/final_data/master.csv')
adp = pd.read_csv('data/rankings/underdog_adps.csv')[['firstName', 'lastName', 'adp', 'projectedPoints', 'positionRank', 'slotName']]
offline_def_projections = pd.read_csv('./data/rankings/2024_offline_def_projections.csv')

# combine firstName and lastName in adp
adp['Player'] = adp['firstName'] + ' ' + adp['lastName']
adp = adp.drop(columns=['firstName', 'lastName'])

# drop target cols from df
master = master.drop(columns=[col for col in master.columns if 'Target' in col])

# get 2023 seasons
master_2023 = master[master['Year'] == 2023]

# %%
# merge
df = master_2023.merge(adp, on='Player', how='left').merge(offline_def_projections, on='Tm', how='left')

# view data
df.head()
# Out:
#             Player   Tm Pos  Age   G  GS  Pass_Cmp  Pass_Att  Pass_Yds  \
# 0   Quintin Morris  BUF  TE   24  15   0         0         0         0
# 1      Geoff Swaim  ARI  TE   30  14   8         0         0         0
# 2   Brycen Hopkins  LAR  TE   26  15   0         0         0         0
# 3        Tim Jones  JAX  WR   25  17   2         0         0         0
# 4  Dare Ogunbowale  HOU  RB   29  12   0         0         0         0
#
#    Pass_TD  Pass_Int  Rush_Att  Rush_Yds  Rush_Y/A  Rush_TD  Rec_Tgt  Rec_Rec  \
# 0        0         0         0         0     0.000        0      3.0        2
# 1        0         0         0         0     0.000        0     11.0       10
# 2        0         0         0         0     0.000        0      7.0        5
# 3        0         0         0         0     0.000        0     18.0       11
# 4        0         0         8        35     4.375        0      7.0        2
#
#    Rec_Yds    Rec_Y/R  Rec_TD  Fmb  FmbLost       Key  Year  Scrim_Yds  \
# 0       26  13.000000       1  0.0      0.0  MorrQu00  2023         26
# 1       94   9.400000       0  0.0      0.0  SwaiGe00  2023         94
# 2       78  15.600000       0  0.0      0.0  HopkBr01  2023         78
# 3       83   7.545455       0  0.0      0.0  JoneTi00  2023         83
# 4       18   9.000000       0  0.0      0.0  OgunDa00  2023         53
#
#    Scrim_TD  num_games  games_played_pct  games_started_pct  ProBowl  AllPro  \
# 0         1         17          0.882353           0.000000    False   False
# 1         0         17          0.823529           0.571429    False   False
# 2         0         17          0.882353           0.000000    False   False
# 3         0         17          1.000000           0.117647    False   False
# 4         0         17          0.705882           0.000000    False   False
#
#    Exp  New_Team  Will_be_on_New_Team  Traded  Pass_Y/A  Touches  Cmp%  \
# 0    1     False                False   False       0.0        2   0.0
# 1    8      True                False   False       0.0       10   0.0
# 2    3     False                False   False       0.0        5   0.0
# 3    1     False                False   False       0.0       11   0.0
# 4    6     False                False   False       0.0       10   0.0
#
#      Catch%  Pass_Cmp_per_game  Pass_Att_per_game  Pass_Yds_per_game  \
# 0  0.666667                0.0                0.0                0.0
# 1  0.909091                0.0                0.0                0.0
# 2  0.714286                0.0                0.0                0.0
# 3  0.611111                0.0                0.0                0.0
# 4  0.285714                0.0                0.0                0.0
#
#    Pass_TD_per_game  Pass_Int_per_game  Rush_Att_per_game  Rush_Yds_per_game  \
# 0               0.0                0.0           0.000000           0.000000
# 1               0.0                0.0           0.000000           0.000000
# 2               0.0                0.0           0.000000           0.000000
# 3               0.0                0.0           0.000000           0.000000
# 4               0.0                0.0           0.666667           2.916667
#
#    Rush_TD_per_game  Rec_Tgt_per_game  Rec_Rec_per_game  Rec_Yds_per_game  \
# 0               0.0          0.200000          0.133333          1.733333
# 1               0.0          0.785714          0.714286          6.714286
# 2               0.0          0.466667          0.333333          5.200000
# 3               0.0          1.058824          0.647059          4.882353
# 4               0.0          0.583333          0.166667          1.500000
#
#    ...  PPT_standard  PPT_half-ppr   PPT_ppr     PPT_6  \
# 0  ...      4.300000      4.800000  5.300000  5.300000
# 1  ...      0.940000      1.440000  1.940000  1.940000
# 2  ...      1.560000      2.060000  2.560000  2.560000
# 3  ...      0.754545      1.254545  1.754545  1.754545
# 4  ...      0.530000      0.630000  0.730000  0.730000
#
#    SeasonOvrRank_standard  SeasonOvrRank_half-ppr  SeasonOvrRank_ppr  \
# 0                   416.0                   428.0              435.0
# 1                   410.0                   390.0              386.0
# 2                   422.0                   420.0              418.0
# 3                   418.0                   394.0              388.0
# 4                   447.0                   449.0              453.0
#
#    SeasonOvrRank_6  SeasonPosRank_standard  SeasonPosRank_half-ppr  \
# 0            436.0                    81.0                    86.0
# 1            388.0                    79.0                    77.0
# 2            422.0                    83.0                    82.0
# 3            390.0                   165.0                   161.0
# 4            455.0                   114.0                   115.0
#
#    SeasonPosRank_ppr  SeasonPosRank_6  PPGOvrRank_standard  \
# 0               89.0             89.0                442.0
# 1               77.0             77.0                436.0
# 2               84.0             84.0                452.0
# 3              160.0            160.0                454.0
# 4              116.0            116.0                464.0
#
#    PPGOvrRank_half-ppr  PPGOvrRank_ppr  PPGOvrRank_6  PPGPosRank_standard  \
# 0                463.0           477.0         479.0                 82.0
# 1                426.0           416.0         416.0                 80.0
# 2                455.0           459.0         461.0                 85.0
# 3                440.0           434.0         434.0                179.0
# 4                480.0           483.0         486.0                122.0
#
#    PPGPosRank_half-ppr  PPGPosRank_ppr  PPGPosRank_6  PPTOvrRank_standard  \
# 0                 88.0            94.0          94.0                  6.0
# 1                 79.0            78.0          78.0                270.0
# 2                 85.0            87.0          87.0                130.0
# 3                178.0           176.0         176.0                301.0
# 4                125.0           127.0         127.0                387.0
#
#    PPTOvrRank_half-ppr  PPTOvrRank_ppr  PPTOvrRank_6  PPTPosRank_standard  \
# 0                  6.0             6.0           6.0                  3.0
# 1                257.0           249.0         249.0                 89.0
# 2                125.0           119.0         119.0                 33.0
# 3                280.0           275.0         275.0                175.0
# 4                399.0           398.0         399.0                 85.0
#
#    PPTPosRank_half-ppr  PPTPosRank_ppr  PPTPosRank_6  VORP_standard_10tm  \
# 0                  3.0             3.0           3.0               -91.9
# 1                 89.0            89.0          89.0               -91.1
# 2                 32.0            32.0          32.0               -92.7
# 3                171.0           167.0         167.0              -128.9
# 4                 85.0            85.0          85.0              -138.8
#
#    VORP_half-ppr_10tm  VORP_ppr_10tm  VORP_6_10tm  VORP_standard_12tm  \
# 0             -117.42         -139.9       -139.9               -81.8
# 1             -112.62         -131.1       -131.1               -81.0
# 2             -116.72         -137.7       -137.7               -82.6
# 3             -163.70         -195.9       -195.9              -118.3
# 4             -159.60         -178.1       -178.1              -130.1
#
#    VORP_half-ppr_12tm  VORP_ppr_12tm  VORP_6_12tm  VORP_standard_10tm_3WR  \
# 0             -104.20        -132.92      -134.92                   -91.9
# 1              -99.40        -124.12      -126.12                   -91.1
# 2             -103.50        -130.72      -132.72                   -92.7
# 3             -151.90        -185.10      -185.10                  -109.9
# 4             -146.04        -167.20      -167.20                  -138.8
#
#    VORP_half-ppr_10tm_3WR  VORP_ppr_10tm_3WR  VORP_6_10tm_3WR  \
# 0                 -117.42             -139.9           -139.9
# 1                 -112.62             -131.1           -131.1
# 2                 -116.72             -137.7           -137.7
# 3                 -145.10             -170.9           -170.9
# 4                 -159.60             -178.1           -178.1
#
#    VORP_standard_12tm_3WR  VORP_half-ppr_12tm_3WR  VORP_ppr_12tm_3WR  \
# 0                  -81.80                 -104.20            -132.92
# 1                  -81.00                  -99.40            -124.12
# 2                  -82.60                 -103.50            -130.72
# 3                  -95.08                 -113.40            -137.90
# 4                 -130.10                 -146.04            -167.20
#
#    VORP_6_12tm_3WR    adp  projectedPoints  positionRank  slotName  \
# 0          -134.92      -             18.0           NaN        TE
# 1          -126.12      -              0.0           NaN        TE
# 2          -132.72      -              0.0           NaN        TE
# 3          -137.90      -             19.9           NaN        WR
# 4          -167.20  216.0             19.4         RB111        RB
#
#    OffLine_rank  Def_rank
# 0           8.0      17.0
# 1          26.0      32.0
# 2          16.0      23.0
# 3           NaN       NaN
# 4          22.0       9.0
#
# [5 rows x 114 columns]

# %%
# create cols
df['Passing Incentive'] = df['Def_rank'] - df['OffLine_rank']
df['Rushing Incentive'] = (df['OffLine_rank'] + df['Def_rank']) / 2

# %%
df[['Team', 'OffLine_rank', 'Def_rank', 'Passing Incentive']].drop_duplicates().sort_values('Passing Incentive', ascending=False).T
# Out:
#                     11    9     6     77    105   7     63    30    36    13   \
# Team                PHI   IND   ATL   DEN   LAC   DET   CAR   BUF    TB   LAR
# OffLine_rank        2.0   3.0   6.0  15.0  12.0   1.0  20.0   8.0  17.0  16.0
# Def_rank           21.0  22.0  24.0  31.0  27.0  10.0  29.0  17.0  25.0  23.0
# Passing Incentive  19.0  19.0  18.0  16.0  15.0   9.0   9.0   9.0   8.0   7.0
#
#                     22    3     28    27    31    68   66    4    19   59   \
# Team                ARI   MIN   CHI   NYG    GB   WAS  PIT   CIN   KC  CLE
# OffLine_rank       26.0  13.0  11.0  29.0  14.0  27.0  9.0  21.0  7.0  4.0
# Def_rank           32.0  18.0  16.0  30.0  15.0  28.0  7.0  19.0  4.0  1.0
# Passing Incentive   6.0   5.0   5.0   1.0   1.0   1.0 -2.0  -2.0 -3.0 -3.0
#
#                    5     64    2     0     39    32    17    26    50    1    \
# Team               NYJ   TEN   MIA   DAL   SEA   LVR   JAC   HOU    NE    SF
# OffLine_rank       5.0  30.0  18.0  10.0  31.0  19.0  23.0  22.0  28.0  24.0
# Def_rank           2.0  26.0  14.0   3.0  20.0   8.0  12.0   9.0  13.0   5.0
# Passing Incentive -3.0  -4.0  -4.0  -7.0 -11.0 -11.0 -11.0 -13.0 -15.0 -19.0
#
#                     24    23   232
# Team                BAL    NO  UNS
# OffLine_rank       25.0  32.0  NaN
# Def_rank            6.0  11.0  NaN
# Passing Incentive -19.0 -21.0  NaN

# %% [markdown]
# - The teams on the left (PHI, IND, ATL) are the most likely to have __high-scoring offenses NOT factoring in skill players__.
# - They are more incentivized to pass given their strong front 5 and weak defense.
# - They could still run the ball if they want, but will likely need to pass in order to keep up with their opponents.

# %%
df[['Team', 'OffLine_rank', 'Def_rank', 'Rushing Incentive']].drop_duplicates().sort_values('Rushing Incentive').T
# Out:
#                   59   5     7    19    0    66    11    9     30    32   \
# Team              CLE  NYJ   DET   KC   DAL  PIT   PHI   IND   BUF   LVR
# OffLine_rank      4.0  5.0   1.0  7.0  10.0  9.0   2.0   3.0   8.0  19.0
# Def_rank          1.0  2.0  10.0  4.0   3.0  7.0  21.0  22.0  17.0   8.0
# Rushing Strength  2.5  3.5   5.5  5.5   6.5  8.0  11.5  12.5  12.5  13.5
#
#                    28    1     31    6     26    24    3     2     17    13   \
# Team               CHI    SF    GB   ATL   HOU   BAL   MIN   MIA   JAC   LAR
# OffLine_rank      11.0  24.0  14.0   6.0  22.0  25.0  13.0  18.0  23.0  16.0
# Def_rank          16.0   5.0  15.0  24.0   9.0   6.0  18.0  14.0  12.0  23.0
# Rushing Strength  13.5  14.5  14.5  15.0  15.5  15.5  15.5  16.0  17.5  19.5
#
#                    105   4     50    36    23    77    63    39    68    64   \
# Team               LAC   CIN    NE    TB    NO   DEN   CAR   SEA   WAS   TEN
# OffLine_rank      12.0  21.0  28.0  17.0  32.0  15.0  20.0  31.0  27.0  30.0
# Def_rank          27.0  19.0  13.0  25.0  11.0  31.0  29.0  20.0  28.0  26.0
# Rushing Strength  19.5  20.0  20.5  21.0  21.5  23.0  24.5  25.5  27.5  28.0
#
#                    22    27   232
# Team               ARI   NYG  UNS
# OffLine_rank      26.0  29.0  NaN
# Def_rank          32.0  30.0  NaN
# Rushing Strength  29.0  29.5  NaN

# %% [markdown]
# - This is a more predictable trait. Teams on the left should run the ball with their strong o-lines and defenses.
# - Teams on the right are very unlikely to run the ball, as they'll likely be playing from behind and have shite o-lines.
# - Once again, these __rankings do not factor in skill players__.

# %%
# look at Exp in 1970
df[df['Year'] == 1970]['Exp'].max()
# Out:
# 21

# %% [markdown]
# ## Team analysis:
# - High __negative values__ in the "diff" col indicate a team that should be weighted more towards offense.
# - High __positive values__ in the "diff" col indicate a team that may score less points.
#
# __ARI__:
# - Worst DEF means they'll likely be playing from behind alot.
# - Gaudy stats for Murray, MHJ, and McBride.
#
# __ATL__:
# - Great line. Bijan should have strong season.
# - However, the weak defense may entice an explosive passing attack as well (London, Pitts).
#
# __BAL__:
# - Bad line but Henry has been good without one throughout his career.
# - Strong def should cancel out for Henry.
# - Quick throws and scrambles for Lamar.
#
# __BUF__:
# - Slightly weighted towards an offensive team.
# - Really like James Cook.
# - Allen should be consistent. Who will explode in the passing game?
#
# __CAR__:
# - Like Arizona, the Panthers should be playing behind a lot
# - __Diontae Johnson__ going as WR35 has extreme upside.
# -
#
# __CHI__:
# -
#
# __CIN__:
# -
#
# __CLE__:
# -
#
# __DAL__:
# -
#
# __DEN__:
# -
#
# __DET__:
# -
#
# __GB__:
# -
#
# __HOU__:
# -
#
# __IND__:
# -
#
# __JAC__:
# -
#
# __KC__:
# -
#
# __LAC__:
# -
#
# __LAR__:
# -
#
# __LVR__:
# -
#
# __MIA__:
# -
#
# __MIN__:
# -
#
# __NE__:
# -
#
# __NO__:
# -
#
# __NYG__:
# -
#
# __NYJ__:
# -
#
# __PHI__:
# - Highest diff. This could be a team that plays in shootouts consistently.
# - Should try to get at least one in the draft.
# - Smith at WR21 could be a league-winning pick
#
# __PIT__:
# -
#
# __SEA__:
# -
#
# __SF__:
# -
#
# __TB__:
# -
#
# __TEN__:
# -
#
# __WAS__:
# -
# -

# %%
def view_player(player):
    return df[df['Player'] == player]

# %%
view_player('Breece Hall')
# Out:
#     Rank  Tier       Player Pos Team  Bye   ADP  Floor  Consensus     FP  \
# 15    16     2  Breece Hall  RB  NYJ   12  1.07  236.2      296.9  295.2
#
#     Ceiling   MVP  OffLine_rank  Def_rank  projected_returner
# 15    366.0  63.9           5.0       2.0                 NaN

# %%
view_player('Bijan Robinson')
# Out:
#     Rank  Tier          Player Pos Team  Bye   ADP  Floor  Consensus     FP  \
# 16    17     2  Bijan Robinson  RB  ATL   12  1.05  229.6      287.4  302.1
#
#     Ceiling   MVP  OffLine_rank  Def_rank  projected_returner
# 16    362.5  63.9           6.0      24.0                 NaN

# %%
df.sort_values('ADP', ascending=True).head(30)
# Out:
#     Rank  Tier               Player Pos Team  Bye   ADP  Floor  Consensus  \
# 9     10     1  Christian McCaffrey  RB   SF    9  1.01  254.8      348.6
# 8      9     1          Tyreek Hill  WR  MIA    6  1.02  273.0      323.6
# 7      8     1          CeeDee Lamb  WR  DAL    7  1.03  279.6      334.2
# 13    14     2    Amon-Ra St. Brown  WR  DET    5  1.04  262.6      298.6
# 16    17     2       Bijan Robinson  RB  ATL   12  1.05  229.6      287.4
# 12    13     2        Ja'Marr Chase  WR  CIN   12  1.06  271.2      289.0
# 15    16     2          Breece Hall  RB  NYJ   12  1.07  236.2      296.9
# 11    12     2     Justin Jefferson  WR  MIN    6  1.08  267.8      301.2
# 19    20     3           A.J. Brown  WR  PHI    5  1.09  238.0      281.3
# 20    21     3         Jahmyr Gibbs  RB  DET    5  1.10  221.1      246.9
# 18    19     3       Garrett Wilson  WR  NYJ   12  2.01  232.8      254.6
# 22    23     3       Saquon Barkley  RB  PHI    5  2.02  215.8      256.4
# 17    18     3           Puka Nacua  WR  LAR    6  2.03  241.6      267.1
# 21    22     3      Jonathan Taylor  RB  IND   14  2.04  227.9      252.5
# 24    25     4       Kyren Williams  RB  LAR    6  2.05  203.4      259.0
# 31    32     4       Travis Etienne  RB  JAC   12  2.06  214.9      237.4
# 28    29     4          Cooper Kupp  WR  LAR    6  2.07  203.5      234.0
# 40    41     5        Isiah Pacheco  RB   KC    6  2.08  203.1      248.2
# 23    24     4         Drake London  WR  ATL   12  2.09  218.7      246.7
# 45    46     5          Josh Jacobs  RB   GB   10  2.10  198.5      232.6
# 44    45     1         Travis Kelce  TE   KC    6  3.01  197.4      225.0
# 39    40     5        Derrick Henry  RB  BAL   14  3.02  204.8      231.8
# 29    30     4         Deebo Samuel  WR   SF    9  3.03  214.6      243.7
# 25    26     4          Chris Olave  WR   NO   12  3.04  222.5      252.1
# 1      2     1      Patrick Mahomes  QB   KC    6  3.05  383.8      402.2
# 35    36     4        Brandon Aiyuk  WR   SF    9  3.06  214.8      238.2
# 51    52     2          Sam LaPorta  TE  DET    5  3.07  189.9      222.3
# 32    33     4        De'Von Achane  RB  MIA    6  3.08  209.0      237.1
# 0      1     1           Josh Allen  QB  BUF   12  3.09  385.2      410.5
# 34    35     4        Davante Adams  WR  LVR   10  3.10  220.7      251.0
#
#        FP  Ceiling    MVP  OffLine_rank  Def_rank  projected_returner
# 9   330.9    407.0   71.3          24.0       5.0                 NaN
# 8   332.9    409.5   71.4          18.0      14.0                 NaN
# 7   367.9    408.3   75.2          10.0       3.0                 NaN
# 13  312.7    359.6   66.1           1.0      10.0                 NaN
# 16  302.1    362.5   63.9           6.0      24.0                 NaN
# 12  308.2    388.3   67.0          21.0      19.0                 NaN
# 15  295.2    366.0   63.9           5.0       2.0                 NaN
# 11  311.4    392.3   67.7          13.0      18.0                 NaN
# 19  267.4    323.6   58.9           2.0      21.0                 NaN
# 20  269.6    334.3   58.0           1.0      10.0                 NaN
# 18  280.4    336.5   59.7           5.0       2.0                 NaN
# 22  253.9    332.6   56.6           2.0      21.0                 NaN
# 17  291.1    337.6   61.4          16.0      23.0                 NaN
# 21  253.2    349.4   57.5           3.0      22.0                 NaN
# 24  239.3    347.0   55.6          16.0      23.0                 NaN
# 31  249.9    299.9   54.0          23.0      12.0                 NaN
# 28  251.2    314.0   54.4          16.0      23.0                 NaN
# 40  230.8    297.8   52.1           7.0       4.0                 NaN
# 23  251.4    316.8   56.2           6.0      24.0                 NaN
# 45  223.1    294.5   50.6          14.0      15.0                 NaN
# 44  235.0    282.0   50.9           7.0       4.0                 NaN
# 39  235.5    303.7   52.4          25.0       6.0                 NaN
# 29  238.4    319.5   54.1          24.0       5.0                 NaN
# 25  252.8    300.9   55.1          32.0      11.0                 NaN
# 1   421.7    480.7  126.4           7.0       4.0                 NaN
# 35  221.4    307.8   52.7          24.0       5.0                 NaN
# 51  213.3    281.6   48.5           1.0      10.0                 NaN
# 32  234.8    333.5   54.0          18.0      14.0                 NaN
# 0   418.7    485.7  128.3           8.0      17.0                 NaN
# 34  242.5    303.1   53.3          19.0       8.0                 NaN

# %% [markdown]
# ## 2024 Questions
# Here we will investigate specific data subsets to further solidify 2024 projections.

# %% [markdown]
# ### Team Swap
# Notable team swaps in 2024:
#
# __QB__:
# - ARod (didn't play in 2023)
# - Kirk Cousins
# - Wilson & Fields
# - Minshew
#
# __RB__:
# - Saquon Barkley
# - Derrick Henry
# - Josh Jacobs
# - Joe Mixon
# - Aaron Jones
# - Swift
# - Pollard
# - Moss
# - Ekeler
#
# __WR__:
# - Stefon Diggs
# - Keenan Allen
# - Ridley
# - Hollywood
# - Diontae
# - Curtis Samuel
# - Jeudy
# - Mike Williams
# - Gabe Davis
#
# No notable swaps at TE in 2024.

# %%
# sort by Year, player

# get all rows where 'New_Team' == 1 and the row before it
df[(df['New_Team'] == 1)]

# compare

# %%
# QBs
# account for injuries (ARod 2023)

# %%
# RBs

# %%
# WRs

# %%
# TEs
