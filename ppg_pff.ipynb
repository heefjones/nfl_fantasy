# %% [markdown]
# # Import Data

# %%
# clear memory
# %reset -f

# helper.py
from helper import *
gc.collect()
# Out:
# 0

# %%
# load data
pff = pd.read_csv('./data/clean/pff_fantasy_data.csv')

# ensure values are sorted properly
pff = pff.sort_values(by=['Key', 'Exp']).reset_index(drop=True)

# drop non-normalized columns
pff = drop_total_volume_cols(pff)

# drop some total volume columns and team-related cols
pff_drops = ['Pass_dropbacks', 'Pass_passing_snaps', 'Pass_aimed_passes', 'Pass_def_gen_pressures', 'Pass_hit_as_threw', 'Pass_sacks', 
             'Rush_gap_attempts', 'Rush_zone_attempts', 'Rush_avoided_tackles', 'Rush_explosive', 
             'Rec_avoided_tackles', 'Rec_contested_receptions', 'Rec_contested_targets', 'Rec_inline_snaps', 'Rec_wide_snaps', 'Rec_slot_snaps', 'Rec_routes', 
             'Team_Tackling Grade', 'Team_Pass Rush Grade', 'Team_Coverage Grade', 'Team_Special Teams Grade', 'Team_Team Grade']
pff = pff.drop(columns=pff_drops)

# rename target col
pff = pff.rename(columns={'PPGTarget_half-ppr': 'target'})

# check a row
pff.sample()
# Out:
#             Player   Tm Pos  Age       Key  Year  games_played_pct  \
# 2140  Kirk Cousins  WAS  QB   27  CousKi00  2015               1.0
#
#       games_started_pct  Exp  Pass_Cmp_per_game  Pass_Att_per_game  \
# 2140                1.0    3            23.6875            33.9375
#
#       Pass_Yds_per_game  Pass_TD_per_game  Pass_Int_per_game  \
# 2140            260.375            1.8125             0.6875
#
#       Rush_Att_per_game  Rush_Yds_per_game  Rush_TD_per_game  \
# 2140              1.625                3.0            0.3125
#
#       Rec_Tgt_per_game  Rec_Rec_per_game  Rec_Yds_per_game  Rec_TD_per_game  \
# 2140               0.0               0.0               0.0              0.0
#
#       Fmb_per_game  FmbLost_per_game  Scrim_TD_per_game  Scrim_Yds_per_game  \
# 2140        0.5625            0.1875             0.3125                 3.0
#
#       Touches_per_game  PPG_half-ppr  PPT_half-ppr  PPGOvrRank_half-ppr  \
# 2140           35.5625       18.7775      0.528014                   17
#
#       PPGPosRank_half-ppr  PPTOvrRank_half-ppr  PPTPosRank_half-ppr   target  \
# 2140                   15                  444                   14  19.5175
#
#       Pass_accuracy_percent  Pass_avg_depth_of_target  Pass_avg_time_to_throw  \
# 2140                   78.5                       8.2                    2.55
#
#       Pass_grades_pass  Pass_Dropback%  Pass_Aimed_passes%  \
# 2140              73.7        0.931818            0.950276
#
#       Pass_Dropped_passes%  Pass_Batted_passes%  Pass_Thrown_away%  \
# 2140              0.050388             0.013566           0.030844
#
#       Pass_Pressure%  Pass_Scramble%  Pass_Sack%  Pass_Pressure_to_sack%  \
# 2140        0.334416        0.006494    0.042208                0.126214
#
#       Pass_BTT%  Pass_TWP%  Pass_First_down%  Rush_elusive_rating  \
# 2140   0.040698    0.03876          0.383057                  0.0
#
#       Rush_grades_run  Rush_longest  Rush_Team_Rush%  \
# 2140             54.6          13.0         0.054321
#
#       Rush_Avoided_tackles_per_attempt  Rush_10+_yard_run%  \
# 2140                               0.0            0.045455
#
#       Rush_15+_yard_run%  Rush_15+_yard_run_yards%  Rush_First_down%  \
# 2140                 0.0                       0.0          0.363636
#
#       Rush_Gap%  Rush_Zone%  Rush_YCO_per_attempt  Rec_avg_depth_of_target  \
# 2140   0.045455    0.181818              0.272727                      0.0
#
#       Rec_caught_percent  Rec_contested_catch_rate  Rec_drop_rate  \
# 2140                 0.0                       0.0            0.0
#
#       Rec_grades_hands_drop  Rec_grades_pass_route  Rec_inline_rate  \
# 2140                    0.0                    0.0              0.0
#
#       Rec_longest  Rec_pass_block_rate  Rec_route_rate  Rec_slot_rate  \
# 2140          0.0                  0.0             0.0            0.0
#
#       Rec_targeted_qb_rating  Rec_wide_rate  \
# 2140                     0.0            0.0
#
#       Rec_yards_after_catch_per_reception  Rec_yards_per_reception  Rec_yprr  \
# 2140                                  0.0                      0.0       0.0
#
#       Rec_Avoided_tackles_per_reception  Rec_First_down%  Rec_Int_per_target  \
# 2140                                0.0              0.0                 0.0
#
#       Rec_YAC%  Rec_Contested_catch_rate  grades_offense  Team_Offense Grade  \
# 2140       0.0                       0.0            62.7                77.8
#
#       Team_Passing Grade  Team_Pass Blocking Grade  Team_Receiving Grade  \
# 2140                72.9                      75.2                  81.4
#
#       Team_Rushing Grade  Team_Run Blocking Grade  Team_Defense Grade  \
# 2140                51.5                     77.6                59.6
#
#       Team_Run Defense Grade  Team_Win%  Team_PPG  Team_PPG_allowed  \
# 2140                    58.1     0.5625     24.25           23.6875
#
#       Team_Pass Defense Grade
# 2140                     59.5

# %% [markdown]
# - We will be using normalized features (per-game stats and other percentages) along with __PPG half-ppr fantasy points__ as the target.
# - This will not punish players for missing games or getting injured (which is unfortunate but very common in the NFL).
# - A [seperate model]() will be trained to determine injury probability based on past volume and games missed.

# %% [markdown]
# # Create Features

# %%
# aggregate data by player
features = create_features(pff)

# show shape and nulls
show_shape_and_nulls(features)
# Out:
# Shape: (11559, 617)
# Null values:
#    Age  Exp  FmbLost_per_game  FmbLost_per_game_3y_mean  \
# 0    0    0                 0                         0
#
#    FmbLost_per_game_3y_std  FmbLost_per_game_career_mean  \
# 0                        0                             0
#
#    FmbLost_per_game_career_std  FmbLost_per_game_career_trend_slope  \
# 0                            0                                    0
#
#    FmbLost_per_game_momentum  Fmb_per_game  Fmb_per_game_3y_mean  \
# 0                          0             0                     0
#
#    Fmb_per_game_3y_std  Fmb_per_game_career_mean  Fmb_per_game_career_std  \
# 0                    0                         0                        0
#
#    Fmb_per_game_career_trend_slope  Fmb_per_game_momentum  Key  \
# 0                                0                      0    0
#
#    PPGOvrRank_half-ppr  PPGOvrRank_half-ppr_3y_mean  \
# 0                    0                            0
#
#    PPGOvrRank_half-ppr_3y_std  PPGOvrRank_half-ppr_career_mean  \
# 0                           0                                0
#
#    PPGOvrRank_half-ppr_career_std  PPGOvrRank_half-ppr_career_trend_slope  \
# 0                               0                                       0
#
#    PPGOvrRank_half-ppr_momentum  PPGPosRank_half-ppr  \
# 0                             0                    0
#
#    PPGPosRank_half-ppr_3y_mean  PPGPosRank_half-ppr_3y_std  \
# 0                            0                           0
#
#    PPGPosRank_half-ppr_career_mean  PPGPosRank_half-ppr_career_std  \
# 0                                0                               0
#
#    PPGPosRank_half-ppr_career_trend_slope  PPGPosRank_half-ppr_momentum  \
# 0                                       0                             0
#
#    PPG_half-ppr  PPG_half-ppr_3y_mean  PPG_half-ppr_3y_std  \
# 0             0                     0                    0
#
#    PPG_half-ppr_career_mean  PPG_half-ppr_career_std  \
# 0                         0                        0
#
#    PPG_half-ppr_career_trend_slope  PPG_half-ppr_momentum  \
# 0                                0                      0
#
#    PPTOvrRank_half-ppr  PPTOvrRank_half-ppr_3y_mean  \
# 0                    0                            0
#
#    PPTOvrRank_half-ppr_3y_std  PPTOvrRank_half-ppr_career_mean  \
# 0                           0                                0
#
#    PPTOvrRank_half-ppr_career_std  PPTOvrRank_half-ppr_career_trend_slope  \
# 0                               0                                       0
#
#    PPTOvrRank_half-ppr_momentum  PPTPosRank_half-ppr  \
# 0                             0                    0
#
#    PPTPosRank_half-ppr_3y_mean  PPTPosRank_half-ppr_3y_std  \
# 0                            0                           0
#
#    PPTPosRank_half-ppr_career_mean  PPTPosRank_half-ppr_career_std  \
# 0                                0                               0
#
#    PPTPosRank_half-ppr_career_trend_slope  PPTPosRank_half-ppr_momentum  \
# 0                                       0                             0
#
#    PPT_half-ppr  PPT_half-ppr_3y_mean  PPT_half-ppr_3y_std  \
# 0             0                     0                    0
#
#    PPT_half-ppr_career_mean  PPT_half-ppr_career_std  \
# 0                         0                        0
#
#    PPT_half-ppr_career_trend_slope  PPT_half-ppr_momentum  Pass_Aimed_passes%  \
# 0                                0                      0                   0
#
#    Pass_Aimed_passes%_3y_mean  Pass_Aimed_passes%_3y_std  \
# 0                           0                          0
#
#    Pass_Aimed_passes%_career_mean  Pass_Aimed_passes%_career_std  \
# 0                               0                              0
#
#    Pass_Aimed_passes%_career_trend_slope  Pass_Aimed_passes%_momentum  \
# 0                                      0                            0
#
#    Pass_Att_per_game  Pass_Att_per_game_3y_mean  Pass_Att_per_game_3y_std  \
# 0                  0                          0                         0
#
#    Pass_Att_per_game_career_mean  Pass_Att_per_game_career_std  \
# 0                              0                             0
#
#    Pass_Att_per_game_career_trend_slope  Pass_Att_per_game_momentum  \
# 0                                     0                           0
#
#    Pass_BTT%  Pass_BTT%_3y_mean  Pass_BTT%_3y_std  Pass_BTT%_career_mean  \
# 0          0                  0                 0                      0
#
#    Pass_BTT%_career_std  Pass_BTT%_career_trend_slope  Pass_BTT%_momentum  \
# 0                     0                             0                   0
#
#    Pass_Batted_passes%  Pass_Batted_passes%_3y_mean  \
# 0                    0                            0
#
#    Pass_Batted_passes%_3y_std  Pass_Batted_passes%_career_mean  \
# 0                           0                                0
#
#    Pass_Batted_passes%_career_std  Pass_Batted_passes%_career_trend_slope  \
# 0                               0                                       0
#
#    Pass_Batted_passes%_momentum  Pass_Cmp_per_game  Pass_Cmp_per_game_3y_mean  \
# 0                             0                  0                          0
#
#    Pass_Cmp_per_game_3y_std  Pass_Cmp_per_game_career_mean  \
# 0                         0                              0
#
#    Pass_Cmp_per_game_career_std  Pass_Cmp_per_game_career_trend_slope  \
# 0                             0                                     0
#
#    Pass_Cmp_per_game_momentum  Pass_Dropback%  Pass_Dropback%_3y_mean  \
# 0                           0               0                       0
#
#    Pass_Dropback%_3y_std  Pass_Dropback%_career_mean  \
# 0                      0                           0
#
#    Pass_Dropback%_career_std  Pass_Dropback%_career_trend_slope  \
# 0                          0                                  0
#
#    Pass_Dropback%_momentum  Pass_Dropped_passes%  \
# 0                        0                     0
#
#    Pass_Dropped_passes%_3y_mean  Pass_Dropped_passes%_3y_std  \
# 0                             0                            0
#
#    Pass_Dropped_passes%_career_mean  Pass_Dropped_passes%_career_std  \
# 0                                 0                                0
#
#    Pass_Dropped_passes%_career_trend_slope  Pass_Dropped_passes%_momentum  \
# 0                                        0                              0
#
#    Pass_First_down%  Pass_First_down%_3y_mean  Pass_First_down%_3y_std  \
# 0                 0                         0                        0
#
#    Pass_First_down%_career_mean  Pass_First_down%_career_std  \
# 0                             0                            0
#
#    Pass_First_down%_career_trend_slope  Pass_First_down%_momentum  \
# 0                                    0                          0
#
#    Pass_Int_per_game  Pass_Int_per_game_3y_mean  Pass_Int_per_game_3y_std  \
# 0                  0                          0                         0
#
#    Pass_Int_per_game_career_mean  Pass_Int_per_game_career_std  \
# 0                              0                             0
#
#    Pass_Int_per_game_career_trend_slope  Pass_Int_per_game_momentum  \
# 0                                     0                           0
#
#    Pass_Pressure%  Pass_Pressure%_3y_mean  Pass_Pressure%_3y_std  \
# 0               0                       0                      0
#
#    Pass_Pressure%_career_mean  Pass_Pressure%_career_std  \
# 0                           0                          0
#
#    Pass_Pressure%_career_trend_slope  Pass_Pressure%_momentum  \
# 0                                  0                        0
#
#    Pass_Pressure_to_sack%  Pass_Pressure_to_sack%_3y_mean  \
# 0                       0                               0
#
#    Pass_Pressure_to_sack%_3y_std  Pass_Pressure_to_sack%_career_mean  \
# 0                              0                                   0
#
#    Pass_Pressure_to_sack%_career_std  \
# 0                                  0
#
#    Pass_Pressure_to_sack%_career_trend_slope  Pass_Pressure_to_sack%_momentum  \
# 0                                          0                                0
#
#    Pass_Sack%  Pass_Sack%_3y_mean  Pass_Sack%_3y_std  Pass_Sack%_career_mean  \
# 0           0                   0                  0                       0
#
#    Pass_Sack%_career_std  Pass_Sack%_career_trend_slope  Pass_Sack%_momentum  \
# 0                      0                              0                    0
#
#    Pass_Scramble%  Pass_Scramble%_3y_mean  Pass_Scramble%_3y_std  \
# 0               0                       0                      0
#
#    Pass_Scramble%_career_mean  Pass_Scramble%_career_std  \
# 0                           0                          0
#
#    Pass_Scramble%_career_trend_slope  Pass_Scramble%_momentum  \
# 0                                  0                        0
#
#    Pass_TD_per_game  Pass_TD_per_game_3y_mean  Pass_TD_per_game_3y_std  \
# 0                 0                         0                        0
#
#    Pass_TD_per_game_career_mean  Pass_TD_per_game_career_std  \
# 0                             0                            0
#
#    Pass_TD_per_game_career_trend_slope  Pass_TD_per_game_momentum  Pass_TWP%  \
# 0                                    0                          0          0
#
#    Pass_TWP%_3y_mean  Pass_TWP%_3y_std  Pass_TWP%_career_mean  \
# 0                  0                 0                      0
#
#    Pass_TWP%_career_std  Pass_TWP%_career_trend_slope  Pass_TWP%_momentum  \
# 0                     0                             0                   0
#
#    Pass_Thrown_away%  Pass_Thrown_away%_3y_mean  Pass_Thrown_away%_3y_std  \
# 0                  0                          0                         0
#
#    Pass_Thrown_away%_career_mean  Pass_Thrown_away%_career_std  \
# 0                              0                             0
#
#    Pass_Thrown_away%_career_trend_slope  Pass_Thrown_away%_momentum  \
# 0                                     0                           0
#
#    Pass_Yds_per_game  Pass_Yds_per_game_3y_mean  Pass_Yds_per_game_3y_std  \
# 0                  0                          0                         0
#
#    Pass_Yds_per_game_career_mean  Pass_Yds_per_game_career_std  \
# 0                              0                             0
#
#    Pass_Yds_per_game_career_trend_slope  Pass_Yds_per_game_momentum  \
# 0                                     0                           0
#
#    Pass_accuracy_percent  Pass_accuracy_percent_3y_mean  \
# 0                      0                              0
#
#    Pass_accuracy_percent_3y_std  Pass_accuracy_percent_career_mean  \
# 0                             0                                  0
#
#    Pass_accuracy_percent_career_std  Pass_accuracy_percent_career_trend_slope  \
# 0                                 0                                         0
#
#    Pass_accuracy_percent_momentum  Pass_avg_depth_of_target  \
# 0                               0                         0
#
#    Pass_avg_depth_of_target_3y_mean  Pass_avg_depth_of_target_3y_std  \
# 0                                 0                                0
#
#    Pass_avg_depth_of_target_career_mean  Pass_avg_depth_of_target_career_std  \
# 0                                     0                                    0
#
#    Pass_avg_depth_of_target_career_trend_slope  \
# 0                                            0
#
#    Pass_avg_depth_of_target_momentum  Pass_avg_time_to_throw  \
# 0                                  0                       0
#
#    Pass_avg_time_to_throw_3y_mean  Pass_avg_time_to_throw_3y_std  \
# 0                               0                              0
#
#    Pass_avg_time_to_throw_career_mean  Pass_avg_time_to_throw_career_std  \
# 0                                   0                                  0
#
#    Pass_avg_time_to_throw_career_trend_slope  Pass_avg_time_to_throw_momentum  \
# 0                                          0                                0
#
#    Pass_grades_pass  Pass_grades_pass_3y_mean  Pass_grades_pass_3y_std  \
# 0                 0                         0                        0
#
#    Pass_grades_pass_career_mean  Pass_grades_pass_career_std  \
# 0                             0                            0
#
#    Pass_grades_pass_career_trend_slope  Pass_grades_pass_momentum  Player  \
# 0                                    0                          0       0
#
#    Pos  Rec_Avoided_tackles_per_reception  \
# 0    0                                  0
#
#    Rec_Avoided_tackles_per_reception_3y_mean  \
# 0                                          0
#
#    Rec_Avoided_tackles_per_reception_3y_std  \
# 0                                         0
#
#    Rec_Avoided_tackles_per_reception_career_mean  \
# 0                                              0
#
#    Rec_Avoided_tackles_per_reception_career_std  \
# 0                                             0
#
#    Rec_Avoided_tackles_per_reception_career_trend_slope  \
# 0                                                  0
#
#    Rec_Avoided_tackles_per_reception_momentum  Rec_Contested_catch_rate  \
# 0                                           0                         0
#
#    Rec_Contested_catch_rate_3y_mean  Rec_Contested_catch_rate_3y_std  \
# 0                                 0                                0
#
#    Rec_Contested_catch_rate_career_mean  Rec_Contested_catch_rate_career_std  \
# 0                                     0                                    0
#
#    Rec_Contested_catch_rate_career_trend_slope  \
# 0                                            0
#
#    Rec_Contested_catch_rate_momentum  Rec_First_down%  \
# 0                                  0                0
#
#    Rec_First_down%_3y_mean  Rec_First_down%_3y_std  \
# 0                        0                       0
#
#    Rec_First_down%_career_mean  Rec_First_down%_career_std  \
# 0                            0                           0
#
#    Rec_First_down%_career_trend_slope  Rec_First_down%_momentum  \
# 0                                   0                         0
#
#    Rec_Int_per_target  Rec_Int_per_target_3y_mean  Rec_Int_per_target_3y_std  \
# 0                   0                           0                          0
#
#    Rec_Int_per_target_career_mean  Rec_Int_per_target_career_std  \
# 0                               0                              0
#
#    Rec_Int_per_target_career_trend_slope  Rec_Int_per_target_momentum  \
# 0                                      0                            0
#
#    Rec_Rec_per_game  Rec_Rec_per_game_3y_mean  Rec_Rec_per_game_3y_std  \
# 0                 0                         0                        0
#
#    Rec_Rec_per_game_career_mean  Rec_Rec_per_game_career_std  \
# 0                             0                            0
#
#    Rec_Rec_per_game_career_trend_slope  Rec_Rec_per_game_momentum  \
# 0                                    0                          0
#
#    Rec_TD_per_game  Rec_TD_per_game_3y_mean  Rec_TD_per_game_3y_std  \
# 0                0                        0                       0
#
#    Rec_TD_per_game_career_mean  Rec_TD_per_game_career_std  \
# 0                            0                           0
#
#    Rec_TD_per_game_career_trend_slope  Rec_TD_per_game_momentum  \
# 0                                   0                         0
#
#    Rec_Tgt_per_game  Rec_Tgt_per_game_3y_mean  Rec_Tgt_per_game_3y_std  \
# 0                 0                         0                        0
#
#    Rec_Tgt_per_game_career_mean  Rec_Tgt_per_game_career_std  \
# 0                             0                            0
#
#    Rec_Tgt_per_game_career_trend_slope  Rec_Tgt_per_game_momentum  Rec_YAC%  \
# 0                                    0                          0         0
#
#    Rec_YAC%_3y_mean  Rec_YAC%_3y_std  Rec_YAC%_career_mean  \
# 0                 0                0                     0
#
#    Rec_YAC%_career_std  Rec_YAC%_career_trend_slope  Rec_YAC%_momentum  \
# 0                    0                            0                  0
#
#    Rec_Yds_per_game  Rec_Yds_per_game_3y_mean  Rec_Yds_per_game_3y_std  \
# 0                 0                         0                        0
#
#    Rec_Yds_per_game_career_mean  Rec_Yds_per_game_career_std  \
# 0                             0                            0
#
#    Rec_Yds_per_game_career_trend_slope  Rec_Yds_per_game_momentum  \
# 0                                    0                          0
#
#    Rec_avg_depth_of_target  Rec_avg_depth_of_target_3y_mean  \
# 0                        0                                0
#
#    Rec_avg_depth_of_target_3y_std  Rec_avg_depth_of_target_career_mean  \
# 0                               0                                    0
#
#    Rec_avg_depth_of_target_career_std  \
# 0                                   0
#
#    Rec_avg_depth_of_target_career_trend_slope  \
# 0                                           0
#
#    Rec_avg_depth_of_target_momentum  Rec_caught_percent  \
# 0                                 0                   0
#
#    Rec_caught_percent_3y_mean  Rec_caught_percent_3y_std  \
# 0                           0                          0
#
#    Rec_caught_percent_career_mean  Rec_caught_percent_career_std  \
# 0                               0                              0
#
#    Rec_caught_percent_career_trend_slope  Rec_caught_percent_momentum  \
# 0                                      0                            0
#
#    Rec_contested_catch_rate  Rec_contested_catch_rate_3y_mean  \
# 0                         0                                 0
#
#    Rec_contested_catch_rate_3y_std  Rec_contested_catch_rate_career_mean  \
# 0                                0                                     0
#
#    Rec_contested_catch_rate_career_std  \
# 0                                    0
#
#    Rec_contested_catch_rate_career_trend_slope  \
# 0                                            0
#
#    Rec_contested_catch_rate_momentum  Rec_drop_rate  Rec_drop_rate_3y_mean  \
# 0                                  0              0                      0
#
#    Rec_drop_rate_3y_std  Rec_drop_rate_career_mean  Rec_drop_rate_career_std  \
# 0                     0                          0                         0
#
#    Rec_drop_rate_career_trend_slope  Rec_drop_rate_momentum  \
# 0                                 0                       0
#
#    Rec_grades_hands_drop  Rec_grades_hands_drop_3y_mean  \
# 0                      0                              0
#
#    Rec_grades_hands_drop_3y_std  Rec_grades_hands_drop_career_mean  \
# 0                             0                                  0
#
#    Rec_grades_hands_drop_career_std  Rec_grades_hands_drop_career_trend_slope  \
# 0                                 0                                         0
#
#    Rec_grades_hands_drop_momentum  Rec_grades_pass_route  \
# 0                               0                      0
#
#    Rec_grades_pass_route_3y_mean  Rec_grades_pass_route_3y_std  \
# 0                              0                             0
#
#    Rec_grades_pass_route_career_mean  Rec_grades_pass_route_career_std  \
# 0                                  0                                 0
#
#    Rec_grades_pass_route_career_trend_slope  Rec_grades_pass_route_momentum  \
# 0                                         0                               0
#
#    Rec_inline_rate  Rec_inline_rate_3y_mean  Rec_inline_rate_3y_std  \
# 0                0                        0                       0
#
#    Rec_inline_rate_career_mean  Rec_inline_rate_career_std  \
# 0                            0                           0
#
#    Rec_inline_rate_career_trend_slope  Rec_inline_rate_momentum  Rec_longest  \
# 0                                   0                         0            0
#
#    Rec_longest_3y_mean  Rec_longest_3y_std  Rec_longest_career_mean  \
# 0                    0                   0                        0
#
#    Rec_longest_career_std  Rec_longest_career_trend_slope  \
# 0                       0                               0
#
#    Rec_longest_momentum  Rec_pass_block_rate  Rec_pass_block_rate_3y_mean  \
# 0                     0                    0                            0
#
#    Rec_pass_block_rate_3y_std  Rec_pass_block_rate_career_mean  \
# 0                           0                                0
#
#    Rec_pass_block_rate_career_std  Rec_pass_block_rate_career_trend_slope  \
# 0                               0                                       0
#
#    Rec_pass_block_rate_momentum  Rec_route_rate  Rec_route_rate_3y_mean  \
# 0                             0               0                       0
#
#    Rec_route_rate_3y_std  Rec_route_rate_career_mean  \
# 0                      0                           0
#
#    Rec_route_rate_career_std  Rec_route_rate_career_trend_slope  \
# 0                          0                                  0
#
#    Rec_route_rate_momentum  Rec_slot_rate  Rec_slot_rate_3y_mean  \
# 0                        0              0                      0
#
#    Rec_slot_rate_3y_std  Rec_slot_rate_career_mean  Rec_slot_rate_career_std  \
# 0                     0                          0                         0
#
#    Rec_slot_rate_career_trend_slope  Rec_slot_rate_momentum  \
# 0                                 0                       0
#
#    Rec_targeted_qb_rating  Rec_targeted_qb_rating_3y_mean  \
# 0                       0                               0
#
#    Rec_targeted_qb_rating_3y_std  Rec_targeted_qb_rating_career_mean  \
# 0                              0                                   0
#
#    Rec_targeted_qb_rating_career_std  \
# 0                                  0
#
#    Rec_targeted_qb_rating_career_trend_slope  Rec_targeted_qb_rating_momentum  \
# 0                                          0                                0
#
#    Rec_wide_rate  Rec_wide_rate_3y_mean  Rec_wide_rate_3y_std  \
# 0              0                      0                     0
#
#    Rec_wide_rate_career_mean  Rec_wide_rate_career_std  \
# 0                          0                         0
#
#    Rec_wide_rate_career_trend_slope  Rec_wide_rate_momentum  \
# 0                                 0                       0
#
#    Rec_yards_after_catch_per_reception  \
# 0                                    0
#
#    Rec_yards_after_catch_per_reception_3y_mean  \
# 0                                            0
#
#    Rec_yards_after_catch_per_reception_3y_std  \
# 0                                           0
#
#    Rec_yards_after_catch_per_reception_career_mean  \
# 0                                                0
#
#    Rec_yards_after_catch_per_reception_career_std  \
# 0                                               0
#
#    Rec_yards_after_catch_per_reception_career_trend_slope  \
# 0                                                  0
#
#    Rec_yards_after_catch_per_reception_momentum  Rec_yards_per_reception  \
# 0                                             0                        0
#
#    Rec_yards_per_reception_3y_mean  Rec_yards_per_reception_3y_std  \
# 0                                0                               0
#
#    Rec_yards_per_reception_career_mean  Rec_yards_per_reception_career_std  \
# 0                                    0                                   0
#
#    Rec_yards_per_reception_career_trend_slope  \
# 0                                           0
#
#    Rec_yards_per_reception_momentum  Rec_yprr  Rec_yprr_3y_mean  \
# 0                                 0         0                 0
#
#    Rec_yprr_3y_std  Rec_yprr_career_mean  Rec_yprr_career_std  \
# 0                0                     0                    0
#
#    Rec_yprr_career_trend_slope  Rec_yprr_momentum  Rush_10+_yard_run%  \
# 0                            0                  0                   0
#
#    Rush_10+_yard_run%_3y_mean  Rush_10+_yard_run%_3y_std  \
# 0                           0                          0
#
#    Rush_10+_yard_run%_career_mean  Rush_10+_yard_run%_career_std  \
# 0                               0                              0
#
#    Rush_10+_yard_run%_career_trend_slope  Rush_10+_yard_run%_momentum  \
# 0                                      0                            0
#
#    Rush_15+_yard_run%  Rush_15+_yard_run%_3y_mean  Rush_15+_yard_run%_3y_std  \
# 0                   0                           0                          0
#
#    Rush_15+_yard_run%_career_mean  Rush_15+_yard_run%_career_std  \
# 0                               0                              0
#
#    Rush_15+_yard_run%_career_trend_slope  Rush_15+_yard_run%_momentum  \
# 0                                      0                            0
#
#    Rush_15+_yard_run_yards%  Rush_15+_yard_run_yards%_3y_mean  \
# 0                         0                                 0
#
#    Rush_15+_yard_run_yards%_3y_std  Rush_15+_yard_run_yards%_career_mean  \
# 0                                0                                     0
#
#    Rush_15+_yard_run_yards%_career_std  \
# 0                                    0
#
#    Rush_15+_yard_run_yards%_career_trend_slope  \
# 0                                            0
#
#    Rush_15+_yard_run_yards%_momentum  Rush_Att_per_game  \
# 0                                  0                  0
#
#    Rush_Att_per_game_3y_mean  Rush_Att_per_game_3y_std  \
# 0                          0                         0
#
#    Rush_Att_per_game_career_mean  Rush_Att_per_game_career_std  \
# 0                              0                             0
#
#    Rush_Att_per_game_career_trend_slope  Rush_Att_per_game_momentum  \
# 0                                     0                           0
#
#    Rush_Avoided_tackles_per_attempt  Rush_Avoided_tackles_per_attempt_3y_mean  \
# 0                                 0                                         0
#
#    Rush_Avoided_tackles_per_attempt_3y_std  \
# 0                                        0
#
#    Rush_Avoided_tackles_per_attempt_career_mean  \
# 0                                             0
#
#    Rush_Avoided_tackles_per_attempt_career_std  \
# 0                                            0
#
#    Rush_Avoided_tackles_per_attempt_career_trend_slope  \
# 0                                                  0
#
#    Rush_Avoided_tackles_per_attempt_momentum  Rush_First_down%  \
# 0                                          0                 0
#
#    Rush_First_down%_3y_mean  Rush_First_down%_3y_std  \
# 0                         0                        0
#
#    Rush_First_down%_career_mean  Rush_First_down%_career_std  \
# 0                             0                            0
#
#    Rush_First_down%_career_trend_slope  Rush_First_down%_momentum  Rush_Gap%  \
# 0                                    0                          0          0
#
#    Rush_Gap%_3y_mean  Rush_Gap%_3y_std  Rush_Gap%_career_mean  \
# 0                  0                 0                      0
#
#    Rush_Gap%_career_std  Rush_Gap%_career_trend_slope  Rush_Gap%_momentum  \
# 0                     0                             0                   0
#
#    Rush_TD_per_game  Rush_TD_per_game_3y_mean  Rush_TD_per_game_3y_std  \
# 0                 0                         0                        0
#
#    Rush_TD_per_game_career_mean  Rush_TD_per_game_career_std  \
# 0                             0                            0
#
#    Rush_TD_per_game_career_trend_slope  Rush_TD_per_game_momentum  \
# 0                                    0                          0
#
#    Rush_Team_Rush%  Rush_Team_Rush%_3y_mean  Rush_Team_Rush%_3y_std  \
# 0                0                        0                       0
#
#    Rush_Team_Rush%_career_mean  Rush_Team_Rush%_career_std  \
# 0                            0                           0
#
#    Rush_Team_Rush%_career_trend_slope  Rush_Team_Rush%_momentum  \
# 0                                   0                         0
#
#    Rush_YCO_per_attempt  Rush_YCO_per_attempt_3y_mean  \
# 0                     0                             0
#
#    Rush_YCO_per_attempt_3y_std  Rush_YCO_per_attempt_career_mean  \
# 0                            0                                 0
#
#    Rush_YCO_per_attempt_career_std  Rush_YCO_per_attempt_career_trend_slope  \
# 0                                0                                        0
#
#    Rush_YCO_per_attempt_momentum  Rush_Yds_per_game  \
# 0                              0                  0
#
#    Rush_Yds_per_game_3y_mean  Rush_Yds_per_game_3y_std  \
# 0                          0                         0
#
#    Rush_Yds_per_game_career_mean  Rush_Yds_per_game_career_std  \
# 0                              0                             0
#
#    Rush_Yds_per_game_career_trend_slope  Rush_Yds_per_game_momentum  \
# 0                                     0                           0
#
#    Rush_Zone%  Rush_Zone%_3y_mean  Rush_Zone%_3y_std  Rush_Zone%_career_mean  \
# 0           0                   0                  0                       0
#
#    Rush_Zone%_career_std  Rush_Zone%_career_trend_slope  Rush_Zone%_momentum  \
# 0                      0                              0                    0
#
#    Rush_elusive_rating  Rush_elusive_rating_3y_mean  \
# 0                    0                            0
#
#    Rush_elusive_rating_3y_std  Rush_elusive_rating_career_mean  \
# 0                           0                                0
#
#    Rush_elusive_rating_career_std  Rush_elusive_rating_career_trend_slope  \
# 0                               0                                       0
#
#    Rush_elusive_rating_momentum  Rush_grades_run  Rush_grades_run_3y_mean  \
# 0                             0                0                        0
#
#    Rush_grades_run_3y_std  Rush_grades_run_career_mean  \
# 0                       0                            0
#
#    Rush_grades_run_career_std  Rush_grades_run_career_trend_slope  \
# 0                           0                                   0
#
#    Rush_grades_run_momentum  Rush_longest  Rush_longest_3y_mean  \
# 0                         0             0                     0
#
#    Rush_longest_3y_std  Rush_longest_career_mean  Rush_longest_career_std  \
# 0                    0                         0                        0
#
#    Rush_longest_career_trend_slope  Rush_longest_momentum  Scrim_TD_per_game  \
# 0                                0                      0                  0
#
#    Scrim_TD_per_game_3y_mean  Scrim_TD_per_game_3y_std  \
# 0                          0                         0
#
#    Scrim_TD_per_game_career_mean  Scrim_TD_per_game_career_std  \
# 0                              0                             0
#
#    Scrim_TD_per_game_career_trend_slope  Scrim_TD_per_game_momentum  \
# 0                                     0                           0
#
#    Scrim_Yds_per_game  Scrim_Yds_per_game_3y_mean  Scrim_Yds_per_game_3y_std  \
# 0                   0                           0                          0
#
#    Scrim_Yds_per_game_career_mean  Scrim_Yds_per_game_career_std  \
# 0                               0                              0
#
#    Scrim_Yds_per_game_career_trend_slope  Scrim_Yds_per_game_momentum  \
# 0                                      0                            0
#
#    Team_Defense Grade  Team_Defense Grade_3y_mean  Team_Defense Grade_3y_std  \
# 0                   0                           0                          0
#
#    Team_Defense Grade_career_mean  Team_Defense Grade_career_std  \
# 0                               0                              0
#
#    Team_Defense Grade_career_trend_slope  Team_Defense Grade_momentum  \
# 0                                      0                            0
#
#    Team_Offense Grade  Team_Offense Grade_3y_mean  Team_Offense Grade_3y_std  \
# 0                   0                           0                          0
#
#    Team_Offense Grade_career_mean  Team_Offense Grade_career_std  \
# 0                               0                              0
#
#    Team_Offense Grade_career_trend_slope  Team_Offense Grade_momentum  \
# 0                                      0                            0
#
#    Team_PPG  Team_PPG_3y_mean  Team_PPG_3y_std  Team_PPG_allowed  \
# 0         0                 0                0                 0
#
#    Team_PPG_allowed_3y_mean  Team_PPG_allowed_3y_std  \
# 0                         0                        0
#
#    Team_PPG_allowed_career_mean  Team_PPG_allowed_career_std  \
# 0                             0                            0
#
#    Team_PPG_allowed_career_trend_slope  Team_PPG_allowed_momentum  \
# 0                                    0                          0
#
#    Team_PPG_career_mean  Team_PPG_career_std  Team_PPG_career_trend_slope  \
# 0                     0                    0                            0
#
#    Team_PPG_momentum  Team_Pass Blocking Grade  \
# 0                  0                         0
#
#    Team_Pass Blocking Grade_3y_mean  Team_Pass Blocking Grade_3y_std  \
# 0                                 0                                0
#
#    Team_Pass Blocking Grade_career_mean  Team_Pass Blocking Grade_career_std  \
# 0                                     0                                    0
#
#    Team_Pass Blocking Grade_career_trend_slope  \
# 0                                            0
#
#    Team_Pass Blocking Grade_momentum  Team_Pass Defense Grade  \
# 0                                  0                        0
#
#    Team_Pass Defense Grade_3y_mean  Team_Pass Defense Grade_3y_std  \
# 0                                0                               0
#
#    Team_Pass Defense Grade_career_mean  Team_Pass Defense Grade_career_std  \
# 0                                    0                                   0
#
#    Team_Pass Defense Grade_career_trend_slope  \
# 0                                           0
#
#    Team_Pass Defense Grade_momentum  Team_Passing Grade  \
# 0                                 0                   0
#
#    Team_Passing Grade_3y_mean  Team_Passing Grade_3y_std  \
# 0                           0                          0
#
#    Team_Passing Grade_career_mean  Team_Passing Grade_career_std  \
# 0                               0                              0
#
#    Team_Passing Grade_career_trend_slope  Team_Passing Grade_momentum  \
# 0                                      0                            0
#
#    Team_Receiving Grade  Team_Receiving Grade_3y_mean  \
# 0                     0                             0
#
#    Team_Receiving Grade_3y_std  Team_Receiving Grade_career_mean  \
# 0                            0                                 0
#
#    Team_Receiving Grade_career_std  Team_Receiving Grade_career_trend_slope  \
# 0                                0                                        0
#
#    Team_Receiving Grade_momentum  Team_Run Blocking Grade  \
# 0                              0                        0
#
#    Team_Run Blocking Grade_3y_mean  Team_Run Blocking Grade_3y_std  \
# 0                                0                               0
#
#    Team_Run Blocking Grade_career_mean  Team_Run Blocking Grade_career_std  \
# 0                                    0                                   0
#
#    Team_Run Blocking Grade_career_trend_slope  \
# 0                                           0
#
#    Team_Run Blocking Grade_momentum  Team_Run Defense Grade  \
# 0                                 0                       0
#
#    Team_Run Defense Grade_3y_mean  Team_Run Defense Grade_3y_std  \
# 0                               0                              0
#
#    Team_Run Defense Grade_career_mean  Team_Run Defense Grade_career_std  \
# 0                                   0                                  0
#
#    Team_Run Defense Grade_career_trend_slope  Team_Run Defense Grade_momentum  \
# 0                                          0                                0
#
#    Team_Rushing Grade  Team_Rushing Grade_3y_mean  Team_Rushing Grade_3y_std  \
# 0                   0                           0                          0
#
#    Team_Rushing Grade_career_mean  Team_Rushing Grade_career_std  \
# 0                               0                              0
#
#    Team_Rushing Grade_career_trend_slope  Team_Rushing Grade_momentum  \
# 0                                      0                            0
#
#    Team_Win%  Team_Win%_3y_mean  Team_Win%_3y_std  Team_Win%_career_mean  \
# 0          0                  0                 0                      0
#
#    Team_Win%_career_std  Team_Win%_career_trend_slope  Team_Win%_momentum  Tm  \
# 0                     0                             0                   0   0
#
#    Touches_per_game  Touches_per_game_3y_mean  Touches_per_game_3y_std  \
# 0                 0                         0                        0
#
#    Touches_per_game_career_mean  Touches_per_game_career_std  \
# 0                             0                            0
#
#    Touches_per_game_career_trend_slope  Touches_per_game_momentum  Year  \
# 0                                    0                          0     0
#
#    games_played_pct  games_played_pct_3y_mean  games_played_pct_3y_std  \
# 0                 0                         0                        0
#
#    games_played_pct_career_mean  games_played_pct_career_std  \
# 0                             0                            0
#
#    games_played_pct_career_trend_slope  games_played_pct_momentum  \
# 0                                    0                          0
#
#    games_started_pct  games_started_pct_3y_mean  games_started_pct_3y_std  \
# 0                  0                          0                         0
#
#    games_started_pct_career_mean  games_started_pct_career_std  \
# 0                              0                             0
#
#    games_started_pct_career_trend_slope  games_started_pct_momentum  \
# 0                                     0                           0
#
#    grades_offense  grades_offense_3y_mean  grades_offense_3y_std  \
# 0               0                       0                      0
#
#    grades_offense_career_mean  grades_offense_career_std  \
# 0                           0                          0
#
#    grades_offense_career_trend_slope  grades_offense_momentum  target
# 0                                  0                        0    3024

# %% [markdown]
# - The only null values are held in the "Target" column (indicating players in their final season). We cannot use rows without a target to train, so they will be dropped here.

# %%
# get 2024 features
features_2024 = features[features['Year'] == 2024].copy()

# drop players with null target values
features = features.dropna(subset='target')

# check
features.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # Positional Subsets

# %%
# get positional subsets
qb, rb, wr_te = get_pos_subsets(features)

# show shapes
qb.shape, rb.shape, wr_te.shape
# Out:
# ((1172, 442), (2431, 470), (4932, 470))

# %% [markdown]
# # Baseline
# - Baseline RMSE scores for the 3 positional subsets using an XGBoost with 1000 trees.

# %%
# iterate through subsets
for pos, data in zip(['QB', 'RB', 'WR/TE'], [qb, rb, wr_te]):
    # cross validate
    model = XGBRegressor(n_jobs=-1, random_state=SEED, n_estimators=1000)
    summary = cross_val(df=data, estimator=model)

    # show results
    print(f'--- {pos} ---')
    display(summary)
# Out:
# --- QB ---
#       train_rmse      train_r2  val_rmse    val_r2
# mean    0.000532  1.000000e+00  5.362118  0.437789
# std     0.000034  6.744251e-10  0.185015  0.038211
# --- RB ---
#       train_rmse      train_r2  val_rmse    val_r2
# mean    0.000680  1.000000e+00  3.623404  0.519875
# std     0.000033  1.783878e-09  0.177472  0.066509
# --- WR/TE ---
#       train_rmse      train_r2  val_rmse    val_r2
# mean    0.000855  1.000000e+00  2.830232  0.575578
# std     0.000077  7.235904e-09  0.071837  0.024063

# %% [markdown]
# - The train metrics are almost perfect, with much worse validation scores.
# - We will run 100 iterations of bayesian optimization on each positional group to regularize and bring the validation scores down.

# %% [markdown]
# # Optimize XGBoost

# %%
# get X and y for the 3 subsets
X_qb, y_qb = get_X_y(qb)
X_rb, y_rb = get_X_y(rb)
X_wr_te, y_wr_te = get_X_y(wr_te)

# define the parameter search space
param_bounds = {'max_depth': (1, 10),
    'learning_rate': (0.0001, 0.01),
    'gamma': (0, 1),
    'subsample': (0, 1.0),
    'colsample_bytree': (0, 1.0),
    'min_child_weight': (0, 10)}

# bayesian optimize
optim_qb = run_bayes_opt(X_qb, y_qb, param_bounds, SEED)
optim_rb = run_bayes_opt(X_rb, y_rb, param_bounds, SEED)
optim_wr_te = run_bayes_opt(X_wr_te, y_wr_te, param_bounds, SEED)
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_depth | min_ch... | subsample |
# -------------------------------------------------------------------------------------------------
# | 1         | -2.809    | 0.01037   | 0.5019    | 0.005008  | 2.204     | 1.421     | 0.2186    |
# | 2         | -3.008    | 0.4185    | 0.2481    | 0.0009322 | 4.109     | 1.668     | 0.8786    |
# | 3         | -2.624    | 0.951     | 0.03875   | 0.007021  | 6.155     | 8.98      | 0.6669    |
# | 4         | -2.616    | 0.5478    | 0.7024    | 0.003926  | 7.25      | 8.249     | 0.4657    |
# | 5         | -2.638    | 0.9405    | 0.8037    | 0.009835  | 2.527     | 5.211     | 0.9455    |
# | 6         | -2.634    | 0.6495    | 0.8608    | 0.009711  | 2.67      | 2.431     | 0.8734    |
# | 7         | -2.624    | 0.9063    | 0.7583    | 0.003534  | 5.172     | 6.105     | 0.4963    |
# | 8         | -2.636    | 0.478     | 0.4356    | 0.008717  | 2.686     | 6.877     | 0.7035    |
# | 9         | -2.663    | 0.9252    | 0.03945   | 0.006506  | 6.742     | 4.617     | 0.05306   |
# | 10        | -2.652    | 0.03857   | 0.1695    | 0.007966  | 2.463     | 1.387     | 0.3529    |
# | 11        | -2.631    | 0.03037   | 0.1438    | 0.008463  | 7.327     | 2.881     | 0.5637    |
# | 12        | -2.614    | 0.05925   | 0.0606    | 0.009837  | 5.968     | 0.2914    | 0.9692    |
# | 13        | -2.619    | 0.06886   | 0.2086    | 0.006033  | 7.109     | 2.374     | 0.9049    |
# | 14        | -2.645    | 0.1513    | 0.4636    | 0.006479  | 2.902     | 3.045     | 0.2063    |
# | 15        | -2.725    | 0.04242   | 0.07904   | 0.002116  | 5.648     | 0.1044    | 0.7576    |
# | 16        | -2.643    | 0.2069    | 0.5346    | 0.002709  | 9.994     | 6.405     | 0.5314    |
# | 17        | -2.617    | 0.06651   | 0.9979    | 0.008807  | 5.171     | 6.193     | 0.4666    |
# | 18        | -2.622    | 0.744     | 0.2702    | 0.006589  | 3.288     | 5.988     | 0.8351    |
# | 19        | -2.643    | 0.06404   | 0.5715    | 0.008002  | 2.159     | 3.988     | 0.4946    |
# | 20        | -2.621    | 0.1819    | 0.6738    | 0.008675  | 6.186     | 8.671     | 0.8897    |
# | 21        | -2.684    | 0.8575    | 0.3703    | 0.001917  | 7.08      | 8.214     | 0.9623    |
# | 22        | -2.66     | 0.3657    | 0.6215    | 0.009582  | 1.425     | 6.678     | 0.9414    |
# | 23        | -2.63     | 0.6807    | 0.08436   | 0.007742  | 8.845     | 1.608     | 0.5277    |
# | 24        | -2.729    | 0.1225    | 0.4674    | 0.002494  | 2.958     | 8.919     | 0.6221    |
# | 25        | -2.679    | 0.01268   | 0.8554    | 0.006737  | 7.024     | 3.705     | 0.5896    |
# | 26        | -2.638    | 0.2618    | 0.3942    | 0.008574  | 2.68      | 7.576     | 0.2192    |
# | 27        | -3.261    | 0.4784    | 0.9938    | 0.0006163 | 5.116     | 3.472     | 0.9231    |
# | 28        | -2.616    | 0.09195   | 0.0       | 0.01      | 7.132     | 0.7159    | 1.0       |
# | 29        | -4.348    | 0.4524    | 0.9251    | 0.01      | 5.904     | 7.476     | 0.0       |
# | 30        | -2.616    | 0.2024    | 0.5617    | 0.005815  | 7.122     | 9.383     | 0.8852    |
# | 31        | -4.108    | 0.2172    | 1.0       | 0.0001    | 4.316     | 5.649     | 0.9102    |
# | 32        | -2.944    | 0.3549    | 0.141     | 0.001019  | 6.401     | 5.055     | 0.5466    |
# | 33        | -2.646    | 0.04877   | 0.8027    | 0.009781  | 2.467     | 0.2472    | 0.17      |
# | 34        | -2.637    | 0.8007    | 0.1798    | 0.009211  | 2.327     | 6.0       | 0.8378    |
# | 35        | -2.679    | 0.8637    | 0.8601    | 0.003447  | 2.455     | 5.129     | 0.9493    |
# | 36        | -4.301    | 0.0       | 0.0       | 0.0001    | 6.18      | 9.458     | 1.0       |
# | 37        | -2.617    | 0.7069    | 0.7621    | 0.004924  | 6.906     | 8.918     | 0.8088    |
# | 38        | -2.983    | 0.0       | 1.0       | 0.01      | 7.184     | 8.641     | 1.0       |
# | 39        | -3.159    | 0.7485    | 0.2718    | 0.0007259 | 7.479     | 8.944     | 0.32      |
# | 40        | -2.633    | 0.9197    | 0.8687    | 0.01      | 2.707     | 6.144     | 0.7812    |
# | 41        | -2.617    | 0.08688   | 0.3379    | 0.004428  | 6.274     | 3.197     | 0.9309    |
# | 42        | -3.619    | 0.5162    | 0.5644    | 0.0003441 | 6.958     | 3.015     | 1.0       |
# | 43        | -2.626    | 0.681     | 0.1281    | 0.003217  | 7.476     | 7.009     | 0.6801    |
# | 44        | -2.627    | 0.2122    | 0.01084   | 0.008048  | 7.906     | 2.199     | 0.5442    |
# | 45        | -2.987    | 0.0       | 0.0       | 0.01      | 7.26      | 2.247     | 0.2964    |
# | 46        | -2.658    | 0.2099    | 0.4431    | 0.00452   | 2.905     | 8.867     | 0.6793    |
# | 47        | -2.635    | 0.3383    | 0.7086    | 0.01      | 2.221     | 6.319     | 0.9106    |
# | 48        | -2.623    | 0.4032    | 0.6124    | 0.006323  | 3.838     | 9.258     | 0.5391    |
# | 49        | -2.636    | 0.4125    | 0.4086    | 0.01      | 2.754     | 6.112     | 0.3782    |
# | 50        | -2.636    | 0.8138    | 0.5483    | 0.009438  | 2.107     | 6.571     | 0.3449    |
# | 51        | -2.631    | 0.4954    | 0.6665    | 0.008242  | 7.146     | 8.195     | 0.4115    |
# | 52        | -2.634    | 0.6403    | 0.4167    | 0.01      | 2.805     | 8.107     | 0.8662    |
# | 53        | -2.633    | 0.9941    | 0.005957  | 0.002739  | 7.566     | 9.205     | 0.6764    |
# | 54        | -2.639    | 0.8814    | 0.7468    | 0.006149  | 2.57      | 5.264     | 0.9372    |
# | 55        | -2.647    | 0.6211    | 0.4531    | 0.003446  | 3.995     | 5.004     | 0.9975    |
# | 56        | -2.659    | 0.9735    | 0.2151    | 0.002743  | 3.399     | 4.846     | 0.7941    |
# | 57        | -2.624    | 0.9246    | 0.4187    | 0.01      | 3.334     | 8.818     | 0.8693    |
# | 58        | -2.635    | 0.8116    | 0.1483    | 0.01      | 2.859     | 8.543     | 0.1956    |
# | 59        | -2.657    | 0.9652    | 0.5033    | 0.01      | 7.412     | 9.742     | 1.0       |
# | 60        | -2.648    | 1.0       | 0.7681    | 0.01      | 6.205     | 8.66      | 1.0       |
# | 61        | -2.634    | 0.8819    | 0.6601    | 0.007827  | 2.5       | 8.869     | 0.7694    |
# | 62        | -2.623    | 0.7309    | 1.0       | 0.01      | 3.172     | 8.414     | 0.3526    |
# | 63        | -2.639    | 0.5308    | 0.7195    | 0.009134  | 2.268     | 8.373     | 0.1076    |
# | 64        | -2.62     | 0.3236    | 0.1189    | 0.006752  | 7.983     | 1.42      | 1.0       |
# | 65        | -2.661    | 0.8657    | 0.9515    | 0.003862  | 2.154     | 7.498     | 0.5836    |
# | 66        | -2.634    | 0.03815   | 0.2352    | 0.007505  | 8.576     | 2.106     | 1.0       |
# | 67        | -3.028    | 0.0       | 0.2393    | 0.008488  | 6.348     | 1.147     | 1.0       |
# | 68        | -2.636    | 0.4568    | 0.7491    | 0.01      | 8.277     | 1.799     | 0.5396    |
# | 69        | -2.637    | 0.1154    | 0.6057    | 0.00923   | 2.19      | 4.056     | 0.5061    |
# | 70        | -3.005    | 0.0       | 0.07815   | 0.01      | 8.42      | 1.344     | 0.2503    |
# | 71        | -2.662    | 0.8906    | 0.07718   | 0.01      | 8.278     | 2.072     | 1.0       |
# | 72        | -2.996    | 0.0       | 0.0       | 0.01      | 8.171     | 2.937     | 0.8419    |
# | 73        | -2.631    | 0.4314    | 0.5907    | 0.00448   | 3.24      | 7.58      | 0.6666    |
# | 74        | -2.658    | 0.3903    | 0.3072    | 0.009578  | 1.702     | 2.278     | 0.6806    |
# | 75        | -2.635    | 0.6668    | 0.5468    | 0.01      | 2.212     | 3.182     | 0.6718    |
# | 76        | -3.546    | 0.9904    | 0.7254    | 0.0004308 | 2.853     | 7.461     | 0.1023    |
# | 77        | -2.648    | 0.03089   | 0.6459    | 0.01      | 2.379     | 7.617     | 0.8725    |
# | 78        | -2.638    | 0.09478   | 0.02805   | 0.01      | 2.418     | 8.212     | 0.4855    |
# | 79        | -2.658    | 0.1768    | 0.0861    | 0.002999  | 3.43      | 8.091     | 0.6597    |
# | 80        | -2.691    | 0.07679   | 0.3288    | 0.002027  | 8.308     | 9.272     | 0.924     |
# | 81        | -2.622    | 0.3321    | 0.8464    | 0.009974  | 3.695     | 8.351     | 0.8691    |
# | 82        | -2.732    | 0.7382    | 0.9623    | 0.001629  | 9.798     | 6.752     | 0.3428    |
# | 83        | -2.995    | 0.4185    | 0.1339    | 0.000928  | 8.138     | 9.186     | 0.6418    |
# | 84        | -2.785    | 0.7309    | 0.8088    | 0.001437  | 8.87      | 8.794     | 0.2068    |
# | 85        | -2.657    | 0.1213    | 0.2549    | 0.004782  | 2.058     | 7.121     | 0.4738    |
# | 86        | -2.675    | 0.6423    | 0.8332    | 0.007194  | 1.162     | 1.325     | 0.8467    |
# | 87        | -3.224    | 0.5667    | 0.5988    | 0.001073  | 1.587     | 7.684     | 0.6173    |
# | 88        | -2.618    | 0.0798    | 0.1548    | 0.009758  | 6.473     | 6.343     | 0.6176    |
# | 89        | -2.653    | 0.3789    | 0.3192    | 0.004602  | 2.864     | 6.153     | 0.3628    |
# | 90        | -2.914    | 0.01873   | 0.1802    | 0.003651  | 1.759     | 1.749     | 0.5403    |
# | 91        | -2.637    | 0.5736    | 0.4512    | 0.006963  | 2.633     | 0.1595    | 0.5748    |
# | 92        | -2.621    | 0.3531    | 0.06814   | 0.003706  | 6.557     | 7.516     | 0.7482    |
# | 93        | -2.795    | 0.2284    | 0.001377  | 0.001549  | 3.037     | 7.355     | 0.8785    |
# | 94        | -2.983    | 0.0       | 0.8132    | 0.01      | 2.931     | 8.107     | 0.5596    |
# | 95        | -2.691    | 0.9       | 0.88      | 0.003086  | 2.478     | 5.138     | 0.9724    |
# | 96        | -2.638    | 0.5105    | 0.1452    | 0.00976   | 2.854     | 4.086     | 0.2982    |
# | 97        | -2.628    | 0.9001    | 0.7757    | 0.01      | 3.149     | 9.143     | 0.2201    |
# | 98        | -2.633    | 1.0       | 0.6813    | 0.01      | 2.189     | 5.578     | 0.3175    |
# | 99        | -2.627    | 0.7299    | 0.4676    | 0.01      | 3.812     | 8.569     | 0.2723    |
# | 100       | -2.637    | 0.8517    | 0.2172    | 0.007728  | 2.378     | 4.883     | 0.4891    |
# | 101       | -2.698    | 0.3453    | 0.464     | 0.002039  | 6.264     | 1.999     | 0.1119    |
# | 102       | -2.631    | 0.08692   | 0.0       | 0.003147  | 6.968     | 6.91      | 1.0       |
# | 103       | -4.107    | 0.9996    | 1.0       | 0.0001    | 3.856     | 8.846     | 0.7151    |
# | 104       | -2.624    | 0.5386    | 0.05744   | 0.01      | 3.449     | 8.85      | 0.4627    |
# | 105       | -2.639    | 0.06007   | 0.1124    | 0.009901  | 2.971     | 2.949     | 0.9099    |
# | 106       | -2.634    | 0.8211    | 1.356e-17 | 0.01      | 2.809     | 8.824     | 0.8645    |
# | 107       | -2.63     | 0.05945   | 0.3753    | 0.01      | 3.935     | 8.655     | 0.3213    |
# | 108       | -2.633    | 1.0       | 0.26      | 0.01      | 2.886     | 5.545     | 0.3871    |
# | 109       | -4.348    | 0.3729    | 0.3437    | 0.01      | 3.618     | 9.328     | 0.0       |
# | 110       | -2.927    | 0.3401    | 0.6824    | 0.00124   | 2.297     | 4.893     | 0.1113    |
# =================================================================================================

# %%
# get best params
best_params_qb = {'colsample_bytree': 0.9508414362373033,
   'gamma': 0.9829511813725073,
   'learning_rate': 0.00818088036451473,
   'max_depth': 3,
   'min_child_weight': 6,
   'subsample': 0.9342989244729221}
best_params_rb = {'colsample_bytree': 0.0868799866187755,
   'gamma': 0.33787049927378343,
   'learning_rate': 0.004427921171525542,
   'max_depth': 6,
   'min_child_weight': 3,
   'subsample': 0.930876891906753}
best_params_wr_te = {'colsample_bytree': 0.05925486884064757,
  'gamma': 0.060595524929000555,
  'learning_rate': 0.009837405785066958,
  'max_depth': 5,
  'min_child_weight': 0,
  'subsample': 0.9691521325098982}

# define models
xgb_qb = XGBRegressor(**best_params_qb, n_estimators=1000, random_state=SEED, n_jobs=-1)
xgb_rb = XGBRegressor(**best_params_rb, n_estimators=1000, random_state=SEED, n_jobs=-1)
xgb_wr_te = XGBRegressor(**best_params_wr_te, n_estimators=1000, random_state=SEED, n_jobs=-1)

# %% [markdown]
# # 2024 Predictions
# Here we will train on the 2006-2022 data and then use the 2023 data as the holdout test set to predict the 2024 grades.

# %%
# get 2024 predictions for each position
print('--- QB ---')
qb_preds = get_2024_preds(qb, xgb_qb)
print('--- RB ---')
rb_preds = get_2024_preds(rb, xgb_rb)
print('--- WR/TE ---')
wr_te_preds = get_2024_preds(wr_te, xgb_wr_te)
# Out:
# --- QB ---
# RMSE: 5.3821
# R2: 0.4298
#
# --- RB ---
# RMSE: 3.2276
# R2: 0.6612
#
# --- WR/TE ---
# RMSE: 2.5214
# R2: 0.6592

# %%
# get replacement-level players (top 12 QBs, 30 RBs, 42 WRs, and 12 TEs)
qb_repl = qb_preds.head(12)
rb_repl = rb_preds.head(30)
wr_repl = wr_te_preds.query('pos == "WR"').head(42)
te_repl = wr_te_preds.query('pos == "TE"').head(12)

# plot QBs and TEs
plot_2024_preds(pd.concat([qb_repl, te_repl]))

# %%
# plot RBs
plot_2024_preds(rb_repl)

# %%
# plot WRs
plot_2024_preds(wr_repl)

# %% [markdown]
# - The pff models also had a tendency to underpredict the top-performing players, but not quite as much as the non-pff data.

# %% [markdown]
# # 2025 Predictions

# %%
# get X and y for the 3 subsets
X_qb, y_qb = get_X_y(qb)
X_rb, y_rb = get_X_y(rb)
X_wr_te, y_wr_te = get_X_y(wr_te)

# %%
# get positional subsets for 2024
qb_2024, rb_2024, wr_te_2024 = get_pos_subsets(features_2024)

# fit models on all other data (1970-2023)
xgb_qb.fit(X_qb, y_qb)
xgb_rb.fit(X_rb, y_rb)
xgb_wr_te.fit(X_wr_te, y_wr_te)

# split WR and TE
wr_2024 = wr_te_2024.query('Pos == "WR"')
te_2024 = wr_te_2024.query('Pos == "TE"')

# get 2025 predictions for each position
qb_preds_2025 = get_2025_preds(qb_2024, xgb_qb)
rb_preds_2025 = get_2025_preds(rb_2024, xgb_rb)
wr_preds_2025 = get_2025_preds(wr_2024, xgb_wr_te)
te_preds_2025 = get_2025_preds(te_2024, xgb_wr_te)

# get replacement-level players (top 12 QBs, 30 RBs, 42 WRs, and 12 TEs)
qb_repl = qb_preds_2025.head(12)
rb_repl = rb_preds_2025.head(30)
wr_repl = wr_preds_2025.head(42)
te_repl = te_preds_2025.head(12)

# %%
# plot QBs
plot_2025_preds(qb_repl, pos='QB', xlabel='Predicted PPG', xmin=15, xmax=22)

# %%
# plot RBs
plot_2025_preds(rb_repl, pos='RB', xlabel='Predicted PPG', xmin=7, xmax=18)

# %%
# plot WRs
plot_2025_preds(wr_repl, pos='WR', xlabel='Predicted PPG', xmin=8, xmax=17)

# %%
# plot TEs
plot_2025_preds(te_repl, pos='TE', xlabel='Predicted PPG', xmin=6, xmax=12)

# %%
# combine and save 2025 preds
preds_2025 = pd.concat([qb_preds_2025, rb_preds_2025, wr_preds_2025, te_preds_2025], axis=0).reset_index(drop=True)[['player', 'team', 'pos', 'y_pred']]

# rename pred col
preds_2025 = preds_2025.rename(columns={'y_pred': 'ppg_pred'})

# save
preds_2025.to_csv('./data/clean/pff_ppg_predictions_2025.csv', index=False)
